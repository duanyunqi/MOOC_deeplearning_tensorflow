# %% [markdown]
# ## 人工数据集生成

# %%
import matplotlib.pyplot as plt
import numpy as np
import tensorflow as tf

# 设置随机数种子
np.random.seed(5)
# Out:
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:519: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:520: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:541: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:542: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:543: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:544: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:545: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# D:\SoftWare\Anaconda3\envs\tensorflow1\lib\site-packages\tensorboard\compat\tensorflow_stub\dtypes.py:550: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
# 直接采用np生成等差数列的方法，生成500个点，每个点的取值在0~100之间
x_data = np.linspace(0,100,500)

# y=3.1234x+2.98+噪声，其中，噪声的维度与x_data一致
y_data = 3.1234 * x_data + 2.98 + np.random.randn(*x_data.shape) * 40

# np.random.randn(d0, d1, ..., dn)是从标准正态分布中返回一个或多个样本值
# 标准正态分布又称为u分布，是以0为均值，1为标准差的正态分布，记为N(0,1)

# %% [markdown]
# ## 利用matplotlib画图

# %%
# 画出随机生成数据的散点图
plt.scatter(x_data, y_data)

# %%
# 画出随机生成数据的散点图
plt.scatter(x_data, y_data)

# 画出我们想要学习得到的目标线性函数y=2x+1
plt.plot(x_data, 2.98+3.1234*x_data, color='red', linewidth=3)

# %% [markdown]
# ## 构建模型

# %%
# 定义训练数据的占位符，x是特征值，y是标签值
x = tf.placeholder('float', name='x')
y = tf.placeholder('float', name='y')


# 定义模型函数
def model(x, w ,b):
    return tf.multiply(x,w) +b


# 创建变量
# TensorFlow变量的声明函数是tf.Variable
# tf.Variable的作用是保存和更新参数
# 变量的初始值可以是随机数、常数或者通过其他变量的初始值计算得到

# 构建线性函数的斜率，变量w
w = tf.Variable(3.0, name='w0')

# 构建线性函数的截距，变量b
b = tf.Variable(2.0, name='b0')

# pred是预测值，前向计算
pred = model(x, w, b)

# %% [markdown]
# ## 训练模型

# %%
# 设置训练参数

# 迭代次数（训练轮数）
train_epochs = 10

# 学习率(建议一般设成0.1-0.01之间)
learning_rate = 0.1

display_step = 20 # 控制显示loss值的粒度

# %% [markdown]
# ## 关于学习率（learning_rate）的设置
#
# 学习率的作用：控制参数更新的幅度。
# 如果学习率设置过大，可能导致参数在极值附近来回摆动，无法保证收敛。
# 如果学习率设置过小，虽然能保证收敛，但优化速度会大大降低，我们需要更多迭代次数才能达到较理想的优化效果。

# %% [markdown]
# ## 定义损失函数

# %%
# 损失函数用于描述预测值与真实值之间的误差，从而指导模型收敛方向
# 常见损失函数：均方差（Mean Square Error, MSE）和交叉熵（cross-entropy）

# L2损失函数
# 采用均方差作为损失函数
loss_function = tf.reduce_mean(tf.square(y-pred))

# %% [markdown]
# ## 定义优化器

# %%
# 定义优化器Optimizer，初始化一个GradientDescentOptimizer
# 设置学习率和优化目标：最小化损失

# 梯度下降优化器
optimmizer = tf.train.GradientDescentOptimizer(learning_rate).minimize(loss_function)

# %% [markdown]
# ## 创建会话

# %%
# 声明会话
sess = tf.Session()

# %%
# 变量初始化
# 在真正执行计算之前，需要将所有变量初始化
# 通过tf.global_variables_initializer函数可实现对所有变量的初始化

init = tf.global_variables_initializer()

sess.run(init)

# %% [markdown]
# ## 迭代训练

# %% [markdown]
# ### 显示损失值

# %%
# 模型训练阶段，设置迭代轮次，每次通过将样本逐个输入模型，进行梯度下降优化操作，每轮迭代后，绘制出模型曲线

step = 0 # 记录训练步数
loss_list = [] # 用于保存loss值的列表

# 开始训练，轮数为epoch，采用SGD随机梯度下降优化方法
for epoch in range(train_epochs):
    for xs, ys in zip(x_data, y_data):
        _, loss = sess.run([optimmizer, loss_function], feed_dict={x: xs, y:ys})
        
        # 显示损失值loss
        # display_step:控制报告的粒度
        # 例如，如果display_step设为2，则将每训练2个样本输出一次损失值
        # 与超参数不同，修改display_step不会更改模型所学习的规律
        loss_list.append(loss)
        step = step + 1
        if step % display_step == 0:
            print('Train Epoch:', '%02d' % (epoch+1), 'Step:%03d' % (step),
                 "loss=", "{:.9f}".format(loss))
            
    b0temp = b.eval(session=sess)
    w0temp = w.eval(session=sess)
    
    plt.plot(x_data, w0temp*x_data+b0temp)# 画图
# Out:
# Train Epoch: 01 Step:020 loss= 535028.875000000
# Train Epoch: 01 Step:040 loss= 353854405006664640196086335839141888.000000000
# Train Epoch: 01 Step:060 loss= nan
# Train Epoch: 01 Step:080 loss= nan
# Train Epoch: 01 Step:100 loss= nan
# Train Epoch: 01 Step:120 loss= nan
# Train Epoch: 01 Step:140 loss= nan
# Train Epoch: 01 Step:160 loss= nan
# Train Epoch: 01 Step:180 loss= nan
# Train Epoch: 01 Step:200 loss= nan
# Train Epoch: 01 Step:220 loss= nan
# Train Epoch: 01 Step:240 loss= nan
# Train Epoch: 01 Step:260 loss= nan
# Train Epoch: 01 Step:280 loss= nan
# Train Epoch: 01 Step:300 loss= nan
# Train Epoch: 01 Step:320 loss= nan
# Train Epoch: 01 Step:340 loss= nan
# Train Epoch: 01 Step:360 loss= nan
# Train Epoch: 01 Step:380 loss= nan
# Train Epoch: 01 Step:400 loss= nan
# Train Epoch: 01 Step:420 loss= nan
# Train Epoch: 01 Step:440 loss= nan
# Train Epoch: 01 Step:460 loss= nan
# Train Epoch: 01 Step:480 loss= nan
# Train Epoch: 01 Step:500 loss= nan
# Train Epoch: 02 Step:520 loss= nan
# Train Epoch: 02 Step:540 loss= nan
# Train Epoch: 02 Step:560 loss= nan
# Train Epoch: 02 Step:580 loss= nan
# Train Epoch: 02 Step:600 loss= nan
# Train Epoch: 02 Step:620 loss= nan
# Train Epoch: 02 Step:640 loss= nan
# Train Epoch: 02 Step:660 loss= nan
# Train Epoch: 02 Step:680 loss= nan
# Train Epoch: 02 Step:700 loss= nan
# Train Epoch: 02 Step:720 loss= nan
# Train Epoch: 02 Step:740 loss= nan
# Train Epoch: 02 Step:760 loss= nan
# Train Epoch: 02 Step:780 loss= nan
# Train Epoch: 02 Step:800 loss= nan
# Train Epoch: 02 Step:820 loss= nan
# Train Epoch: 02 Step:840 loss= nan
# Train Epoch: 02 Step:860 loss= nan
# Train Epoch: 02 Step:880 loss= nan
# Train Epoch: 02 Step:900 loss= nan
# Train Epoch: 02 Step:920 loss= nan
# Train Epoch: 02 Step:940 loss= nan
# Train Epoch: 02 Step:960 loss= nan
# Train Epoch: 02 Step:980 loss= nan
# Train Epoch: 02 Step:1000 loss= nan
# Train Epoch: 03 Step:1020 loss= nan
# Train Epoch: 03 Step:1040 loss= nan
# Train Epoch: 03 Step:1060 loss= nan
# Train Epoch: 03 Step:1080 loss= nan
# Train Epoch: 03 Step:1100 loss= nan
# Train Epoch: 03 Step:1120 loss= nan
# Train Epoch: 03 Step:1140 loss= nan
# Train Epoch: 03 Step:1160 loss= nan
# Train Epoch: 03 Step:1180 loss= nan
# Train Epoch: 03 Step:1200 loss= nan
# Train Epoch: 03 Step:1220 loss= nan
# Train Epoch: 03 Step:1240 loss= nan
# Train Epoch: 03 Step:1260 loss= nan
# Train Epoch: 03 Step:1280 loss= nan
# Train Epoch: 03 Step:1300 loss= nan
# Train Epoch: 03 Step:1320 loss= nan
# Train Epoch: 03 Step:1340 loss= nan
# Train Epoch: 03 Step:1360 loss= nan
# Train Epoch: 03 Step:1380 loss= nan
# Train Epoch: 03 Step:1400 loss= nan
# Train Epoch: 03 Step:1420 loss= nan
# Train Epoch: 03 Step:1440 loss= nan
# Train Epoch: 03 Step:1460 loss= nan
# Train Epoch: 03 Step:1480 loss= nan
# Train Epoch: 03 Step:1500 loss= nan
# Train Epoch: 04 Step:1520 loss= nan
# Train Epoch: 04 Step:1540 loss= nan
# Train Epoch: 04 Step:1560 loss= nan
# Train Epoch: 04 Step:1580 loss= nan
# Train Epoch: 04 Step:1600 loss= nan
# Train Epoch: 04 Step:1620 loss= nan
# Train Epoch: 04 Step:1640 loss= nan
# Train Epoch: 04 Step:1660 loss= nan
# Train Epoch: 04 Step:1680 loss= nan
# Train Epoch: 04 Step:1700 loss= nan
# Train Epoch: 04 Step:1720 loss= nan
# Train Epoch: 04 Step:1740 loss= nan
# Train Epoch: 04 Step:1760 loss= nan
# Train Epoch: 04 Step:1780 loss= nan
# Train Epoch: 04 Step:1800 loss= nan
# Train Epoch: 04 Step:1820 loss= nan
# Train Epoch: 04 Step:1840 loss= nan
# Train Epoch: 04 Step:1860 loss= nan
# Train Epoch: 04 Step:1880 loss= nan
# Train Epoch: 04 Step:1900 loss= nan
# Train Epoch: 04 Step:1920 loss= nan
# Train Epoch: 04 Step:1940 loss= nan
# Train Epoch: 04 Step:1960 loss= nan
# Train Epoch: 04 Step:1980 loss= nan
# Train Epoch: 04 Step:2000 loss= nan
# Train Epoch: 05 Step:2020 loss= nan
# Train Epoch: 05 Step:2040 loss= nan
# Train Epoch: 05 Step:2060 loss= nan
# Train Epoch: 05 Step:2080 loss= nan
# Train Epoch: 05 Step:2100 loss= nan
# Train Epoch: 05 Step:2120 loss= nan
# Train Epoch: 05 Step:2140 loss= nan
# Train Epoch: 05 Step:2160 loss= nan
# Train Epoch: 05 Step:2180 loss= nan
# Train Epoch: 05 Step:2200 loss= nan
# Train Epoch: 05 Step:2220 loss= nan
# Train Epoch: 05 Step:2240 loss= nan
# Train Epoch: 05 Step:2260 loss= nan
# Train Epoch: 05 Step:2280 loss= nan
# Train Epoch: 05 Step:2300 loss= nan
# Train Epoch: 05 Step:2320 loss= nan
# Train Epoch: 05 Step:2340 loss= nan
# Train Epoch: 05 Step:2360 loss= nan
# Train Epoch: 05 Step:2380 loss= nan
# Train Epoch: 05 Step:2400 loss= nan
# Train Epoch: 05 Step:2420 loss= nan
# Train Epoch: 05 Step:2440 loss= nan
# Train Epoch: 05 Step:2460 loss= nan
# Train Epoch: 05 Step:2480 loss= nan
# Train Epoch: 05 Step:2500 loss= nan
# Train Epoch: 06 Step:2520 loss= nan
# Train Epoch: 06 Step:2540 loss= nan
# Train Epoch: 06 Step:2560 loss= nan
# Train Epoch: 06 Step:2580 loss= nan
# Train Epoch: 06 Step:2600 loss= nan
# Train Epoch: 06 Step:2620 loss= nan
# Train Epoch: 06 Step:2640 loss= nan
# Train Epoch: 06 Step:2660 loss= nan
# Train Epoch: 06 Step:2680 loss= nan
# Train Epoch: 06 Step:2700 loss= nan
# Train Epoch: 06 Step:2720 loss= nan
# Train Epoch: 06 Step:2740 loss= nan
# Train Epoch: 06 Step:2760 loss= nan
# Train Epoch: 06 Step:2780 loss= nan
# Train Epoch: 06 Step:2800 loss= nan
# Train Epoch: 06 Step:2820 loss= nan
# Train Epoch: 06 Step:2840 loss= nan
# Train Epoch: 06 Step:2860 loss= nan
# Train Epoch: 06 Step:2880 loss= nan
# Train Epoch: 06 Step:2900 loss= nan
# Train Epoch: 06 Step:2920 loss= nan
# Train Epoch: 06 Step:2940 loss= nan
# Train Epoch: 06 Step:2960 loss= nan
# Train Epoch: 06 Step:2980 loss= nan
# Train Epoch: 06 Step:3000 loss= nan
# Train Epoch: 07 Step:3020 loss= nan
# Train Epoch: 07 Step:3040 loss= nan
# Train Epoch: 07 Step:3060 loss= nan
# Train Epoch: 07 Step:3080 loss= nan
# Train Epoch: 07 Step:3100 loss= nan
# Train Epoch: 07 Step:3120 loss= nan
# Train Epoch: 07 Step:3140 loss= nan
# Train Epoch: 07 Step:3160 loss= nan
# Train Epoch: 07 Step:3180 loss= nan
# Train Epoch: 07 Step:3200 loss= nan
# Train Epoch: 07 Step:3220 loss= nan
# Train Epoch: 07 Step:3240 loss= nan
# Train Epoch: 07 Step:3260 loss= nan
# Train Epoch: 07 Step:3280 loss= nan
# Train Epoch: 07 Step:3300 loss= nan
# Train Epoch: 07 Step:3320 loss= nan
# Train Epoch: 07 Step:3340 loss= nan
# Train Epoch: 07 Step:3360 loss= nan
# Train Epoch: 07 Step:3380 loss= nan
# Train Epoch: 07 Step:3400 loss= nan
# Train Epoch: 07 Step:3420 loss= nan
# Train Epoch: 07 Step:3440 loss= nan
# Train Epoch: 07 Step:3460 loss= nan
# Train Epoch: 07 Step:3480 loss= nan
# Train Epoch: 07 Step:3500 loss= nan
# Train Epoch: 08 Step:3520 loss= nan
# Train Epoch: 08 Step:3540 loss= nan
# Train Epoch: 08 Step:3560 loss= nan
# Train Epoch: 08 Step:3580 loss= nan
# Train Epoch: 08 Step:3600 loss= nan
# Train Epoch: 08 Step:3620 loss= nan
# Train Epoch: 08 Step:3640 loss= nan
# Train Epoch: 08 Step:3660 loss= nan
# Train Epoch: 08 Step:3680 loss= nan
# Train Epoch: 08 Step:3700 loss= nan
# Train Epoch: 08 Step:3720 loss= nan
# Train Epoch: 08 Step:3740 loss= nan
# Train Epoch: 08 Step:3760 loss= nan
# Train Epoch: 08 Step:3780 loss= nan
# Train Epoch: 08 Step:3800 loss= nan
# Train Epoch: 08 Step:3820 loss= nan
# Train Epoch: 08 Step:3840 loss= nan
# Train Epoch: 08 Step:3860 loss= nan
# Train Epoch: 08 Step:3880 loss= nan
# Train Epoch: 08 Step:3900 loss= nan
# Train Epoch: 08 Step:3920 loss= nan
# Train Epoch: 08 Step:3940 loss= nan
# Train Epoch: 08 Step:3960 loss= nan
# Train Epoch: 08 Step:3980 loss= nan
# Train Epoch: 08 Step:4000 loss= nan
# Train Epoch: 09 Step:4020 loss= nan
# Train Epoch: 09 Step:4040 loss= nan
# Train Epoch: 09 Step:4060 loss= nan
# Train Epoch: 09 Step:4080 loss= nan
# Train Epoch: 09 Step:4100 loss= nan
# Train Epoch: 09 Step:4120 loss= nan
# Train Epoch: 09 Step:4140 loss= nan
# Train Epoch: 09 Step:4160 loss= nan
# Train Epoch: 09 Step:4180 loss= nan
# Train Epoch: 09 Step:4200 loss= nan
# Train Epoch: 09 Step:4220 loss= nan
# Train Epoch: 09 Step:4240 loss= nan
# Train Epoch: 09 Step:4260 loss= nan
# Train Epoch: 09 Step:4280 loss= nan
# Train Epoch: 09 Step:4300 loss= nan
# Train Epoch: 09 Step:4320 loss= nan
# Train Epoch: 09 Step:4340 loss= nan
# Train Epoch: 09 Step:4360 loss= nan
# Train Epoch: 09 Step:4380 loss= nan
# Train Epoch: 09 Step:4400 loss= nan
# Train Epoch: 09 Step:4420 loss= nan
# Train Epoch: 09 Step:4440 loss= nan
# Train Epoch: 09 Step:4460 loss= nan
# Train Epoch: 09 Step:4480 loss= nan
# Train Epoch: 09 Step:4500 loss= nan
# Train Epoch: 10 Step:4520 loss= nan
# Train Epoch: 10 Step:4540 loss= nan
# Train Epoch: 10 Step:4560 loss= nan
# Train Epoch: 10 Step:4580 loss= nan
# Train Epoch: 10 Step:4600 loss= nan
# Train Epoch: 10 Step:4620 loss= nan
# Train Epoch: 10 Step:4640 loss= nan
# Train Epoch: 10 Step:4660 loss= nan
# Train Epoch: 10 Step:4680 loss= nan
# Train Epoch: 10 Step:4700 loss= nan
# Train Epoch: 10 Step:4720 loss= nan
# Train Epoch: 10 Step:4740 loss= nan
# Train Epoch: 10 Step:4760 loss= nan
# Train Epoch: 10 Step:4780 loss= nan
# Train Epoch: 10 Step:4800 loss= nan
# Train Epoch: 10 Step:4820 loss= nan
# Train Epoch: 10 Step:4840 loss= nan
# Train Epoch: 10 Step:4860 loss= nan
# Train Epoch: 10 Step:4880 loss= nan
# Train Epoch: 10 Step:4900 loss= nan
# Train Epoch: 10 Step:4920 loss= nan
# Train Epoch: 10 Step:4940 loss= nan
# Train Epoch: 10 Step:4960 loss= nan
# Train Epoch: 10 Step:4980 loss= nan
# Train Epoch: 10 Step:5000 loss= nan

# %%
# 模型训练阶段，设置迭代轮次，每次通过将样本逐个输入模型，进行梯度下降优化操作，每轮迭代后，绘制出模型曲线

step = 0 # 记录训练步数
loss_list = [] # 用于保存loss值的列表

# 开始训练，轮数为epoch，采用SGD随机梯度下降优化方法
for epoch in range(train_epochs):
    for xs, ys in zip(x_data, y_data):
        _, loss = sess.run([optimmizer, loss_function], feed_dict={x: xs, y:ys})
        
        # 显示损失值loss
        # display_step:控制报告的粒度
        # 例如，如果display_step设为2，则将每训练2个样本输出一次损失值
        # 与超参数不同，修改display_step不会更改模型所学习的规律
        loss_list.append(loss)
        step = step + 1
        if step % display_step == 0:
            print('Train Epoch:', '%02d' % (epoch+1), 'Step:%03d' % (step),
                 "loss=", "{:.9f}".format(loss))
            
    b0temp = b.eval(session=sess)
    w0temp = w.eval(session=sess)
    
    plt.plot(x_data, w0temp*x_data+b0temp)# 画图

# %% [markdown]
# ## 打印结果

# %%
print('w:', sess.run(w))
print('b:', sess.run(b) )

# %% [markdown]
# ## 图形化显示损失值

# %%
plt.plot(loss_list)

# %%
plt.plot(loss_list, 'r+')

# %%
[x for x in loss_list if x>1]

# %% [markdown]
# ## 随机梯度下降
# 在梯度下降法中，批量指的是用于在单次迭代中计算梯度的样本总数。
#
# 假定批量是指整个数据集，数据集通常包含很大样本（数万甚至数千亿），此外，数据集通常包含多个特征。因此，一个批量可能相当巨大。如果是超大批量，则单词迭代就可能要花费很长时间进行计算。
#
# 随机梯度下降法（SGD）每次迭代只使用一个样本（批量大小为1），如果进行足够的迭代，SGD也可以发挥作用。“随机”这一术语表示构成各个批量的一个样本都是随机选择的。
#
# 小批量随机梯度下降法（小批量SGD）是介于全批量与SGD之间的折衷方案。小批量通常包含10-1000个随机选择的样本。小批量SGD可以减少SGD中的杂乱样本数量，但仍然 比全批量更高效。

# %% [markdown]
# ## 进行预测

# %%
x_test = 3.21

predict = sess.run(pred, feed_dict={x:x_test})
print('预测值：%f'%predict)

target = 2*x_test + 1.0
print('目标值：%f'%target)
